# %% [markdown]
# # Scraping Game Reviews
#
# For this project, we'll scrape data from metacritic in order to try and see which games may be worth playing under quarantine...
#
# ## Import libraries

# %%
#For data wrangling
import pandas as pd
import numpy as np

#For webscraping
from bs4 import BeautifulSoup
import requests
import re
import datetime
import time

#For data visualisation
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from PythonFunctions.cb91visuals import *

# %%
def get_games_by_platform_and_letter(platform,letter):
    
    #Get the page URL, according to the platform and starting letter
    url = f'https://www.metacritic.com/browse/games/title/{platform}/{letter}?page=0'
    headers = {'User-Agent':
           'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.76 Safari/537.36'}
    
    #Request the URL, and make soup from the HTML
    page = requests.get(url, headers = headers)
    soup = BeautifulSoup(page.content, 'html.parser')
    
    #Isolate the page links, which will tell us how many pages we have of this letter
    pagelinks = soup.find('div', class_="pages")
    
    #Get the number of the last page, so we can set a sensible loop later on
    try:
        last_page = int(pagelinks.find('li',class_="page last_page").get_text().replace('…',''))
    except:
        last_page = 0
    
    #Instantiate a dataframe
    df = pd.DataFrame(columns = ['GameTitle','Platform',
                                 'MetaRating','UserRating',
                                 'ReleaseDate','GameURL',
                                 'ReviewsURL'])
    id_count = 0
    
    
    startstrip = "\n\n                            "
    endstrip = "\n                                                    \n"
    
    for i in list(range(max(1,last_page))):
        
        if letter == '#':
            url = f'https://www.metacritic.com/browse/games/title/{platform}?page={i}'
        else:
            url = f'https://www.metacritic.com/browse/games/title/{platform}/{letter}?page={i}'
        
        print(url)
        
        page = requests.get(url, headers = headers)
        soup = BeautifulSoup(page.content, 'html.parser')
        
        games = soup.find('ol', class_="list_products")
        
        artists = [re.search('\nArtist:\n(.*)\n',
                     i.findAll('li',class_="stat product_artist")[0].get_text()).group(1)
           for i in albums.findAll('li',class_="product")]
        
        
        album_titles = [re.search(f'{startstrip}(.*){endstrip}',
                          i.findAll('div',class_="basic_stat product_title")[0].get_text()).group(1)
                for i in albums.findAll('li',class_="product")]

        
        meta_ratings = [list(list(i)[1])[3].get_text().replace('\n','')
                        for i in albums.findAll('li',class_="product")]

        
        release_dates = [i.findAll('li',class_="stat release_date full_release_date")[0].get_text(
                 ).replace('\n','').replace('Release Date:','') 
                 for i in albums.findAll('li',class_="product")]
        
        album_urls = [f"https://www.metacritic.com{i.attrs['href']}" for i in albums.findAll('a')]
        
                      
        review_urls = [f"https://www.metacritic.com{i.attrs['href']}/critic-reviews" for i in albums.findAll('a')]
        
                      
        album_ids = [f"{letter}{100000+id_count+i}" for i in range(len(artists))]
        
        id_count += len(album_ids)
        
        
        new_df = pd.DataFrame({'AlbumID':album_ids,
                               'Album':album_titles,
                               'Artist':artists,
                               'MetaRating':meta_ratings,
                               'ReleaseDate':release_dates,
                               'AlbumURL':album_urls,
                               'ReviewsURL':review_urls})
        
        df = pd.concat([df, new_df])
        
        time.sleep(round(3*np.random.random(),2))
        
    return df

# %%
url = f'https://www.metacritic.com/browse/games/title/xboxone/c?page=0'
headers = {'User-Agent':
       'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.76 Safari/537.36'}

page = requests.get(url, headers = headers)
soup = BeautifulSoup(page.content, 'html.parser')

pagelinks = soup.find('div', class_="pages")

# %%
soup.find('div', class_="pages")
# Out:
# <div class="pages">
# <div class="label">Page:</div>
# <ul class="pages"><li class="page first_page active_page"><span class="page_num">1</span></li><li class="page last_page"><a class="page_num" href="/browse/games/title/xboxone/c?page=1">2</a></li></ul>
# </div>

# %%
int(pagelinks.find('li',class_="page last_page").get_text().replace('…',''))
# Out:
# 2

# %%
games = soup.find('ol', class_="list_products")

# %%
games
# Out:
# <ol class="list_products list_product_condensed">
# <li class="product game_product first_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/cabelas-african-adventures">
#                             Cabela's African Adventures
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game tbd">tbd</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_tbd">tbd</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Mar 17, 2015</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/cafe-express-o">
#                             Cafe Express-o
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game tbd">tbd</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_tbd">tbd</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Jan 15, 2018</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/call-of-cthulhu">
#                             Call of Cthulhu
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game mixed">66</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_mixed">6.0</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Oct 30, 2018</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/call-of-duty-advanced-warfare">
#                             Call of Duty: Advanced Warfare
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game positive">81</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_mixed">5.5</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Nov  3, 2014</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/call-of-duty-advanced-warfare---ascendance">
#                             Call of Duty: Advanced Warfare - Ascendance
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game positive">75</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_mixed">6.6</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Mar 31, 2015</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/call-of-duty-advanced-warfare---havoc">
#                             Call of Duty: Advanced Warfare - Havoc
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game mixed">72</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_mixed">6.4</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Jan 27, 2015</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/call-of-duty-advanced-warfare---reckoning">
#                             Call of Duty: Advanced Warfare - Reckoning
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game positive">75</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_mixed">5.8</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Aug  4, 2015</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/call-of-duty-advanced-warfare---supremacy">
#                             Call of Duty: Advanced Warfare - Supremacy
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game mixed">71</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_mixed">6.4</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Jun  2, 2015</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/call-of-duty-black-ops-4">
#                             Call of Duty: Black Ops 4
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game positive">85</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_unfavorable">4.0</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Oct 12, 2018</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/call-of-duty-black-ops-4---ancient-evil">
#                             Call of Duty: Black Ops 4 - Ancient Evil
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game tbd">tbd</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_tbd">tbd</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Apr  2, 2019</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/call-of-duty-black-ops-iii">
#                             Call of Duty: Black Ops III
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game positive">81</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_unfavorable">4.5</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Nov  6, 2015</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/call-of-duty-black-ops-iii---awakening">
#                             Call of Duty: Black Ops III - Awakening
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game tbd">tbd</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_tbd">tbd</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Mar  3, 2016</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/call-of-duty-black-ops-iii---gold-edition">
#                             Call of Duty: Black Ops III - Gold Edition
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game tbd">tbd</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_tbd">tbd</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Jul 12, 2016</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/call-of-duty-black-ops-iii---salvation">
#                             Call of Duty: Black Ops III - Salvation
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game tbd">tbd</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_tbd">tbd</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Sep  6, 2016</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/call-of-duty-black-ops-iii---the-giant">
#                             Call of Duty: Black Ops III - The Giant
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game tbd">tbd</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_tbd">tbd</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Nov  6, 2015</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/call-of-duty-black-ops-iii---zombies-chronicles">
#                             Call of Duty: Black Ops III - Zombies Chronicles
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game tbd">tbd</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_tbd">tbd</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">May 16, 2017</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/call-of-duty-black-ops-iii-eclipse">
#                             Call of Duty: Black Ops III: Eclipse
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game tbd">tbd</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_tbd">tbd</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">May 19, 2016</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/call-of-duty-ghosts">
#                             Call of Duty: Ghosts
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game positive">78</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_unfavorable">4.3</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Nov 19, 2013</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/call-of-duty-ghosts---devastation">
#                             Call of Duty: Ghosts - Devastation
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game mixed">70</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_mixed">5.8</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Apr  3, 2014</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/call-of-duty-ghosts---invasion">
#                             Call of Duty: Ghosts - Invasion
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game mixed">73</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_mixed">6.3</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Jun  3, 2014</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/call-of-duty-ghosts---nemesis">
#                             Call of Duty: Ghosts - Nemesis
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game tbd">tbd</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_mixed">5.4</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Jul 31, 2014</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/call-of-duty-ghosts---onslaught">
#                             Call of Duty: Ghosts - Onslaught
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game tbd">tbd</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_terrible">1.8</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Nov  8, 2016</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/case-animatronics">
#                             CASE: Animatronics
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game tbd">tbd</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_tbd">tbd</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Oct 21, 2017</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/casey-powell-lacrosse-16">
#                             Casey Powell Lacrosse 16
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game mixed">60</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_favorable">7.6</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Mar  9, 2016</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/casey-powell-lacrosse-18">
#                             Casey Powell Lacrosse 18
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game tbd">tbd</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_mixed">7.0</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Apr 17, 2018</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/casino-high-low">
#                             Casino High Low
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game tbd">tbd</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_tbd">tbd</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Nov 21, 2018</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/cast-of-the-seven-godsends-redux">
#                             Cast of the Seven Godsends: Redux
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game mixed">61</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_mixed">6.0</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Jul 20, 2016</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/castaway-paradise">
#                             Castaway Paradise
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game negative">46</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# ...
# <a href="/game/xbox-one/children-of-morta">
#                             Children of Morta
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game positive">80</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_favorable">7.6</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Oct 15, 2019</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/children-of-zodiarcs">
#                             Children of Zodiarcs
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game tbd">tbd</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_tbd">tbd</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Mar 27, 2020</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/chime-sharp">
#                             Chime Sharp
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game positive">75</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_unfavorable">2.1</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Feb 24, 2017</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/chivalry-medieval-warfare">
#                             Chivalry: Medieval Warfare
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game mixed">51</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_unfavorable">4.1</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Dec  2, 2015</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/christmas-delivery">
#                             Christmas Delivery
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game tbd">tbd</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_tbd">tbd</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Dec 15, 2017</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/christopher-brookmyres-bedlam">
#                             Christopher Brookmyre's Bedlam
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game mixed">59</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_tbd">tbd</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Oct 16, 2015</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/chroma-squad">
#                             Chroma Squad
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game tbd">tbd</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_tbd">tbd</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">May 19, 2017</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/chromagun">
#                             ChromaGun
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game tbd">tbd</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_favorable">7.5</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Aug 23, 2017</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/chronus-arc">
#                             Chronus Arc
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game tbd">tbd</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_tbd">tbd</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Oct 10, 2018</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/circuit-breakers">
#                             Circuit Breakers
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game mixed">62</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_tbd">tbd</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Aug 16, 2017</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/circuits">
#                             Circuits
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game tbd">tbd</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_tbd">tbd</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Dec 15, 2017</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/citadel-forged-with-fire">
#                             Citadel: Forged with Fire
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game mixed">63</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_mixed">6.4</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Nov  1, 2019</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/cities-skylines---campus">
#                             Cities: Skylines - Campus
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game tbd">tbd</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_tbd">tbd</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Sep 24, 2019</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/cities-skylines---green-cities">
#                             Cities: Skylines - Green Cities
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game tbd">tbd</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_tbd">tbd</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Jan 31, 2019</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/cities-skylines---industries">
#                             Cities: Skylines - Industries
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game tbd">tbd</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_tbd">tbd</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Jun 18, 2019</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/cities-skylines---mass-transit">
#                             Cities: Skylines - Mass Transit
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game tbd">tbd</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_tbd">tbd</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Aug  9, 2018</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/cities-skylines---natural-disasters">
#                             Cities: Skylines - Natural Disasters
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game tbd">tbd</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_tbd">tbd</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">May 15, 2018</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/cities-skylines---parklife">
#                             Cities: Skylines - Parklife
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game tbd">tbd</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_tbd">tbd</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Mar 28, 2019</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/cities-skylines---parklife-edition">
#                             Cities: Skylines - Parklife Edition
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game tbd">tbd</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_tbd">tbd</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Nov 12, 2019</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="product game_product last_product">
# <div class="product_wrap">
# <div class="basic_stat product_title">
# <a href="/game/xbox-one/cities-skylines---premium-edition">
#                             Cities: Skylines - Premium Edition
#                                                             (XONE)
#                                                     </a>
# </div>
# <div class="basic_stat product_score brief_metascore">
# <div class="metascore_w small game tbd">tbd</div>
# </div>
# <div class="more_stats condensed_stats">
# <ul class="more_stats">
# <li class="stat product_avguserscore">
# <span class="label">User:</span>
# <span class="data textscore textscore_tbd">tbd</span>
# </li>
# <li class="stat release_date full_release_date">
# <span class="label">Release Date:</span>
# <span class="data">Nov 14, 2017</span>
# </li>
# </ul>
# </div>
# </div>
# </li>
# </ol>
